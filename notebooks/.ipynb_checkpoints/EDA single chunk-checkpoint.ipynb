# %%
import numpy as np
import seaborn as sns
import pandas as pd

import matplotlib.pyplot as plt

import keijzer_exogan as ke

from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm

# %matplotlib inline
# %config InlineBackend.print_figure_kwargs={'facecolor' : "w"} # Make sure the axis background of plots is white, this is usefull for the black theme in JupyterLab

# Initialize default seaborn layout
sns.set_palette(sns.hls_palette(8, l=.3, s=.8))
sns.set(style='ticks')

# %% [markdown]
# # Load chunck

# %%
path = '/datb/16011015/ExoGAN_data//'
filenames = 'chunck_0.pkgz'

X = ke.load_all_to_array(path, filenames)
# Out:
# 100%|██████████| 1/1 [00:11<00:00, 11.68s/it]

# %%
print('X contains %s dictionaries' % len(X))
X[0].keys()
# Out:
# X contains 100000 dictionaries
# dict_keys(['data', 'param'])

# %%
X[0]['data'].keys(), X[0]['param'].keys()
# Out:
# (dict_keys(['spectrum']),
#  dict_keys(['planet_mass', 'temperature_profile', 'ch4_mixratio', 'planet_radius', 'h2o_mixratio', 'co2_mixratio', 'co_mixratio']))

# %% [markdown]
# # Combine $(R_p/R_s)^2$ with wavelengths

# %%
wavelengths = ke.load_wavelengths()

# %%
# Calling R/R -> y and wavelengths -> x to keep it short for now

spectrum = X[0]['data']['spectrum']
df = ke.combine_spectrum_with_wavelengths(spectrum, wavelengths)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 2 columns):
# y    515 non-null float64
# x    515 non-null float64
# dtypes: float64(2)
# memory usage: 8.1 KB

# %%
plt = ke.plot_spectrum(df.x, df.y)

plt.savefig('plots/sample_spectrum.png', dpi=1200)

# %% [markdown]
# # Plot more spectra

# %%
n = 4 # number of spectra to plot

indices = np.random.randint(0, len(X), size=n)

spectra = [X[i]['data']['spectrum'] for i in indices] # load the n randomly selected spectra into an array

df = pd.DataFrame(spectra).T # take the transpose so axis 0 are the R/R values
df['x'] = wavelengths


for i in range(n):
    ke.plot_spectrum(df.x, df[i])

# %%
"""
Do the same thing but put it in one figure (with more spectra)
"""

n = 5 # number of spectra to plot

indices = np.random.randint(0, len(X), size=n)

spectra = [X[i]['data']['spectrum'] for i in indices] # load the n randomly selected spectra into an array

df = pd.DataFrame(spectra).T # take the transpose so axis 0 are the R/R values
df['x'] = wavelengths

i=0
y = df[i].values.reshape(-1,1)
y.shape
# Out:
# (515, 1)

# %%
plt.figure(figsize=(10,5))

for i in range(n):
    plt.plot(df.x, df[i])
    
plt.xlabel(r'Wavelength [µm]')
plt.ylabel(r'$(R_P / R_S)^2$')

plt.grid(True, which="both", ls='-')
    

plt.xscale('log')

# %%
plt.figure(figsize=(10,5))

for i in range(n):
    y = df[i].values.reshape(-1,1)
    scaler = MinMaxScaler(feature_range=(0,1)).fit(y)
    y = scaler.transform(y)

    plt.plot(df.x, y, '.-', ms=3)
    
plt.xlabel(r'Wavelength [µm]')
plt.ylabel(r'Scaled $(R_P / R_S)^2$')

plt.grid(True, which="both", ls='-')
    

plt.xscale('log')

# %%
# Visualizing param ditribution

# %%
X[0]['param'].keys()
# Out:
# dict_keys(['planet_mass', 'temperature_profile', 'ch4_mixratio', 'planet_radius', 'h2o_mixratio', 'co2_mixratio', 'co_mixratio'])

# %%
X[0]['param']
# Out:
# {'planet_mass': 2.7837333333333334e+27,
#  'temperature_profile': 1888.888888888889,
#  'ch4_mixratio': 2.1544346900318865e-06,
#  'planet_radius': 55928800.0,
#  'h2o_mixratio': 1e-08,
#  'co2_mixratio': 2.1544346900318865e-06,
#  'co_mixratio': 2.1544346900318865e-06}

# %%
pd.DataFrame(X[0]['param'], index=[0])
# Out:
#     planet_mass  temperature_profile  ch4_mixratio  planet_radius  \
# 0  2.783733e+27          1888.888889      0.000002     55928800.0
#
#    h2o_mixratio  co2_mixratio  co_mixratio
# 0  1.000000e-08      0.000002     0.000002

# %%
params = [pd.DataFrame(X[i]['param'], index=[0]) for i in tqdm(range(len(X)))]
# Out:
# 100%|██████████| 100000/100000 [00:46<00:00, 2150.43it/s]

# %%
params = pd.concat(params)
params.head()
# Out:
#     planet_mass  temperature_profile  ch4_mixratio  planet_radius  \
# 0  2.783733e+27          1888.888889  2.154435e-06   5.592880e+07
# 0  3.036800e+27          1333.333333  1.291550e-05   8.311641e+07
# 0  2.277600e+27          1777.777778  1.291550e-05   8.311641e+07
# 0  3.036800e+27          1666.666667  1.291550e-05   8.311641e+07
# 0  2.277600e+27          2000.000000  3.593814e-07   6.136632e+07
#
#    h2o_mixratio  co2_mixratio   co_mixratio
# 0  1.000000e-08  2.154435e-06  2.154435e-06
# 0  3.593814e-07  1.000000e-01  5.994843e-08
# 0  1.291550e-05  5.994843e-08  1.000000e-01
# 0  7.742637e-05  2.154435e-06  4.641589e-04
# 0  5.994843e-08  1.000000e-01  3.593814e-07

# %%
params.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 0
# Data columns (total 7 columns):
# planet_mass            100000 non-null float64
# temperature_profile    100000 non-null float64
# ch4_mixratio           100000 non-null float64
# planet_radius          100000 non-null float64
# h2o_mixratio           100000 non-null float64
# co2_mixratio           100000 non-null float64
# co_mixratio            100000 non-null float64
# dtypes: float64(7)
# memory usage: 6.1 MB

# %%
params.describe()
# Out:
#         planet_mass  temperature_profile  ch4_mixratio  planet_radius  \
# count  1.000000e+05        100000.000000  1.000000e+05   1.000000e+05
# mean   2.657116e+27          1499.253333  1.203316e-02   8.042250e+07
# std    7.275005e+26           319.119106  2.977971e-02   1.564301e+07
# min    1.518400e+27          1000.000000  1.000000e-08   5.592880e+07
# 25%    2.024533e+27          1222.222222  3.593814e-07   6.680384e+07
# 50%    2.783733e+27          1555.555556  7.742637e-05   7.767889e+07
# 75%    3.289867e+27          1777.777778  2.782559e-03   9.399146e+07
# max    3.796000e+27          2000.000000  1.000000e-01   1.048665e+08
#
#        h2o_mixratio  co2_mixratio   co_mixratio
# count  1.000000e+05  1.000000e+05  1.000000e+05
# mean   1.203310e-02  1.200386e-02  1.197042e-02
# std    2.978020e-02  2.973343e-02  2.973189e-02
# min    1.000000e-08  1.000000e-08  1.000000e-08
# 25%    3.593814e-07  3.593814e-07  3.593814e-07
# 50%    1.291550e-05  7.742637e-05  1.291550e-05
# 75%    2.782559e-03  2.782559e-03  2.782559e-03
# max    1.000000e-01  1.000000e-01  1.000000e-01

# %%
sns.pairplot(params)

# %% [markdown]
# # Visualizing the distribution of X and y

# %%
# Shuffle X along the first axis to make the order of simulations random
np.random.shuffle(X) # note that X = np.rand.... isn't required

# %% [markdown]
# ## Extracting information from dict and put it in a df

# %%
X[0]['param'].keys()
# Out:
# dict_keys(['planet_mass', 'temperature_profile', 'ch4_mixratio', 'planet_radius', 'h2o_mixratio', 'co2_mixratio', 'co_mixratio'])

# %%
"""
Extract data of all the samples, combine it into two arrays. 
Could be mroe efficient, but this is just for EDA purposes
"""

spectra = []
indices = []

for i in range(100):
    spectrum = X[i]['data']['spectrum'] # get the wavelength values
    spectrum_index = np.arange(0, len(sample)) # get the index values   
    
    spectra.append(spectrum)
    indices.append(spectrum_index)
    
    
spectra = np.array(spectra).flatten()
indices = np.array(indices).flatten()


print(spectra.shape, indices.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-9751334f6e3a> in <module>
#       9 for i in range(100):
#      10     spectrum = X[i]['data']['spectrum'] # get the wavelength values
# ---> 11     spectrum_index = np.arange(0, len(sample)) # get the index values
#      12
#      13     spectra.append(spectrum)
#
# NameError: name 'sample' is not defined

# %%
# Convert the arrays to a pandas dataframe
df1 = pd.DataFrame({"indices":indices, "spectra":spectra})
df1.head()
# Out:
#    indices   spectra
# 0        0  0.021153
# 1        1  0.021111
# 2        2  0.021099
# 3        3  0.021133
# 4        4  0.021099

# %%
# Construct the same type of df containing all the parameter info

# Visualization of the transformation for one sample
df2= pd.DataFrame.from_dict(X[0], orient='index')
df2
# Out:
#                                                 spectrum   planet_mass  \
# data   [0.02115342899660508, 0.02111110715903557, 0.0...           NaN
# param                                                NaN  2.783733e+27
#
#        temperature_profile  ch4_mixratio  planet_radius  h2o_mixratio  \
# data                   NaN           NaN            NaN           NaN
# param          1111.111111      0.000464   9.942898e+07           0.1
#
#        co2_mixratio   co_mixratio
# data            NaN           NaN
# param  5.994843e-08  3.593814e-07

# %%
df2.drop(columns='spectrum').dropna() # First drops the spectrum row, then drops the NaNs in the data row
# Out:
#         planet_mass  temperature_profile  ch4_mixratio  planet_radius  \
# param  2.783733e+27          1111.111111      0.000464   9.942898e+07
#
#        h2o_mixratio  co2_mixratio   co_mixratio
# param           0.1  5.994843e-08  3.593814e-07

# %%
# lets do this for all the samples (that are selected)
dfs2 = []
for i in range(100):
    df2= pd.DataFrame.from_dict(X[i], orient='index')
    df2 = df2.drop(columns='spectrum').dropna() # First drops the spectrum row, then drops the NaNs in the data row
    dfs2.append(df2)

df2 = pd.concat(dfs2) # Concat the list of dfs to one df

# %%
df2.head()
# Out:
#         planet_mass  temperature_profile  ch4_mixratio  planet_radius  \
# param  2.783733e+27          1111.111111      0.000464   9.942898e+07
# param  3.796000e+27          1666.666667      0.000077   7.767889e+07
# param  1.518400e+27          1888.888889      0.000077   6.136632e+07
# param  3.036800e+27          1666.666667      0.002783   9.942898e+07
# param  3.542933e+27          1333.333333      0.000464   1.048665e+08
#
#        h2o_mixratio  co2_mixratio   co_mixratio
# param  1.000000e-01  5.994843e-08  3.593814e-07
# param  5.994843e-08  2.782559e-03  1.668101e-02
# param  3.593814e-07  2.154435e-06  3.593814e-07
# param  1.000000e-08  7.742637e-05  1.668101e-02
# param  3.593814e-07  2.154435e-06  2.782559e-03

# %% [markdown]
# # df1 and df2 are ready for EDA
# Note that the plots of even 'only' 100 samples take a bit to be generated due to the point density.

# %% [markdown]
# ## Spectrum distribution

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51500 entries, 0 to 51499
# Data columns (total 2 columns):
# indices    51500 non-null int64
# spectra    51500 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 804.8 KB

# %%
df1.describe()
# Out:
#             indices       spectra
# count  51500.000000  51500.000000
# mean     257.000000      0.013632
# std      148.668857      0.005195
# min        0.000000      0.006480
# 25%      128.000000      0.009425
# 50%      257.000000      0.012883
# 75%      386.000000      0.016881
# max      514.000000      0.026268

# %%
sns.jointplot(df1.indices, df1.spectra, joint_kws={"s":0.1, "alpha":0.3})
# Out:
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# %%time

sns.jointplot(x="indices", y="spectra", data=df1, kind="kde")
# Out:
# CPU times: user 44.1 s, sys: 214 ms, total: 44.3 s
# Wall time: 14.9 s

# %%
# %%time

f, ax = plt.subplots(figsize=(6, 6))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(df1.indices, df1.spectra, cmap=cmap, n_levels=60, shade=True);
# Out:
# CPU times: user 44.7 s, sys: 252 ms, total: 45 s
# Wall time: 15 s

# %% [markdown]
# ## Param distribution

# %%
df2.columns
# Out:
# Index(['planet_mass', 'temperature_profile', 'ch4_mixratio', 'planet_radius',
#        'h2o_mixratio', 'co2_mixratio', 'co_mixratio'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, param to param
# Data columns (total 7 columns):
# planet_mass            100 non-null float64
# temperature_profile    100 non-null float64
# ch4_mixratio           100 non-null float64
# planet_radius          100 non-null float64
# h2o_mixratio           100 non-null float64
# co2_mixratio           100 non-null float64
# co_mixratio            100 non-null float64
# dtypes: float64(7)
# memory usage: 6.2+ KB

# %%
df2.describe()
# Out:
#         planet_mass  temperature_profile  ch4_mixratio  planet_radius  \
# count  1.000000e+02           100.000000  1.000000e+02   1.000000e+02
# mean   2.642016e+27          1545.555556  1.713019e-02   7.833139e+07
# std    7.409333e+26           330.551429  3.532671e-02   1.509108e+07
# min    1.518400e+27          1000.000000  1.000000e-08   5.592880e+07
# 25%    2.024533e+27          1222.222222  3.593814e-07   6.680384e+07
# 50%    2.783733e+27          1611.111111  4.641589e-04   7.767889e+07
# 75%    3.289867e+27          1888.888889  6.257171e-03   8.855393e+07
# max    3.796000e+27          2000.000000  1.000000e-01   1.048665e+08
#
#        h2o_mixratio  co2_mixratio   co_mixratio
# count  1.000000e+02  1.000000e+02  1.000000e+02
# mean   1.182888e-02  8.981000e-03  1.323732e-02
# std    3.128913e-02  2.558192e-02  3.111922e-02
# min    1.000000e-08  1.000000e-08  1.000000e-08
# 25%    3.593814e-07  3.593814e-07  3.593814e-07
# 50%    1.291550e-05  1.291550e-05  1.291550e-05
# 75%    4.641589e-04  2.782559e-03  2.782559e-03
# max    1.000000e-01  1.000000e-01  1.000000e-01

# %%
sns.pairplot(df2)

# %%
# Get the distribution of the complete (loaded) dataset
spectra = []
indices = []

for i in range(len(X)):
    spectrum = X[i]['data']['spectrum'] # get the wavelength values
    spectrum_index = np.arange(0, len(sample)) # get the index values   
    
    spectra.append(spectrum)
    indices.append(spectrum_index)
    
    
spectra = np.array(spectra).flatten()
indices = np.array(indices).flatten()

df1 = pd.DataFrame({"indices":indices, "spectra":spectra})

# %%
dfs2 = []
for i in range(100):
    df2= pd.DataFrame.from_dict(X[i], orient='index')
    df2 = df2.drop(columns='spectrum').dropna() # First drops the spectrum row, then drops the NaNs in the data row
    dfs2.append(df2)

df2 = pd.concat(dfs2) # Concat the list of dfs to one df

# %%
# %%time
df1.describe()
# Out:
# CPU times: user 54.1 s, sys: 9.73 s, total: 1min 3s
# Wall time: 6.1 s
#             indices       spectra
# count  5.150000e+07  5.150000e+07
# mean   2.570000e+02  1.443345e-02
# std    1.486674e+02  5.556946e-03
# min    0.000000e+00  6.472850e-03
# 25%    1.280000e+02  9.457117e-03
# 50%    2.570000e+02  1.384540e-02
# 75%    3.860000e+02  1.897269e-02
# max    5.140000e+02  3.017950e-02

# %%
# %%time
df2.describe()
# Out:
# CPU times: user 7.65 ms, sys: 7.96 ms, total: 15.6 ms
# Wall time: 14.4 ms
#         planet_mass  temperature_profile  ch4_mixratio  planet_radius  \
# count  1.000000e+02           100.000000  1.000000e+02   1.000000e+02
# mean   2.642016e+27          1545.555556  1.713019e-02   7.833139e+07
# std    7.409333e+26           330.551429  3.532671e-02   1.509108e+07
# min    1.518400e+27          1000.000000  1.000000e-08   5.592880e+07
# 25%    2.024533e+27          1222.222222  3.593814e-07   6.680384e+07
# 50%    2.783733e+27          1611.111111  4.641589e-04   7.767889e+07
# 75%    3.289867e+27          1888.888889  6.257171e-03   8.855393e+07
# max    3.796000e+27          2000.000000  1.000000e-01   1.048665e+08
#
#        h2o_mixratio  co2_mixratio   co_mixratio
# count  1.000000e+02  1.000000e+02  1.000000e+02
# mean   1.182888e-02  8.981000e-03  1.323732e-02
# std    3.128913e-02  2.558192e-02  3.111922e-02
# min    1.000000e-08  1.000000e-08  1.000000e-08
# 25%    3.593814e-07  3.593814e-07  3.593814e-07
# 50%    1.291550e-05  1.291550e-05  1.291550e-05
# 75%    4.641589e-04  2.782559e-03  2.782559e-03
# max    1.000000e-01  1.000000e-01  1.000000e-01

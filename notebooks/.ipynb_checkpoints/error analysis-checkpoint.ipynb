# %%
import numpy as np
import seaborn as sns
import pandas as pd

import matplotlib.pyplot as plt

import keijzer_exogan as ke

from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm

from sklearn.metrics import r2_score

# %matplotlib inline
# %config InlineBackend.print_figure_kwargs={'facecolor' : "w"} # Make sure the axis background of plots is white, this is usefull for the black theme in JupyterLab

# Initialize default seaborn layout
sns.set_palette(sns.hls_palette(8, l=.3, s=.8))
sns.set(style='ticks')

# %%
df = pd.read_csv('Validation error of 300 images')
df.head()
# Out:
#    Unnamed: 0  planet_mass_error  temp_profile_error  ch4_mixratio_error  \
# 0           0           5.661163           31.361074           -2.327390
# 1           0         -13.048820           -4.089689          -18.805864
# 2           0          78.932011           -7.405640          -11.204942
# 3           0           0.201200           12.775918          -10.427065
# 4           0         -20.523508           53.794920          -10.669709
#
#    planet_radius_error  h2o_mixratio_error  co2_mixratio_error  \
# 0             4.737051           24.952615           62.101305
# 1           -12.189896           12.601827           -7.587653
# 2             5.870980          -10.245773          -10.385621
# 3             2.849062           -3.088335          -12.340510
# 4            -7.284073           -0.112408            2.501071
#
#    co_mixratio_error  planet_mass_real  temp_profile_real  \
# 0          26.327365      2.783733e+27        1111.111112
# 1         213.024861      3.542933e+27        1666.666687
# 2         -17.940168      1.518400e+27        1666.666687
# 3         -26.639497      2.783733e+27        1333.333343
# 4         146.518672      3.542933e+27        1000.000000
#
#            ...            h2o_mixratio_real  co2_mixratio_real  \
# 0          ...                   -11.257083          -2.302585
# 1          ...                    -7.675284         -18.420681
# 2          ...                   -14.838882         -13.047982
# 3          ...                    -5.884384          -7.675284
# 4          ...                    -5.884384         -16.629781
#
#    co_mixratio_real  planet_mass_inpainted  temp_profile_inpainted  \
# 0         -7.675284           2.941325e+27             1459.567487
# 1         -2.302585           3.080622e+27             1598.505199
# 2        -13.047982           2.716904e+27             1543.239355
# 3        -14.838882           2.789334e+27             1503.678918
# 4         -4.093484           2.815799e+27             1537.949204
#
#    ch4_mixratio_inpainted  planet_radius_inpainted  h2o_mixratio_inpainted  \
# 0               -5.747431             8.135858e+07              -14.066019
# 1               -4.777775             8.730869e+07               -8.642510
# 2               -8.405503             8.223940e+07              -13.318524
# 3               -6.874977             8.548445e+07               -5.702654
# 4              -14.855432             8.210360e+07               -5.877769
#
#    co2_mixratio_inpainted  co_mixratio_inpainted
# 0               -3.732520              -9.695984
# 1              -17.022983              -7.207663
# 2              -11.692868             -10.707152
# 3               -6.728115             -10.885878
# 4              -17.045704             -10.091203
#
# [5 rows x 22 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0  planet_mass_error  temp_profile_error  ch4_mixratio_error  \
# count       299.0         299.000000          299.000000          299.000000
# mean          0.0          15.713422            5.895516            5.340291
# std           0.0          35.242684           23.907377           28.527681
# min           0.0         -30.863006          -29.398108          -37.968818
# 25%           0.0         -13.255513          -14.327465          -11.078034
# 50%           0.0           4.940959            1.186970           -3.135292
# 75%           0.0          41.357334           21.641297           11.209554
# max           0.0          98.688519           67.424035          123.908460
#
#        planet_radius_error  h2o_mixratio_error  co2_mixratio_error  \
# count           299.000000          299.000000          299.000000
# mean              9.065622           16.242172            8.564769
# std              20.059364           40.747182           29.029305
# min             -19.468898          -45.547231          -29.644180
# 25%              -7.641582           -8.667321           -7.610574
# 50%               4.667664            2.551014            0.331295
# 75%              24.730897           28.035599           13.385505
# max              50.851026          157.668662          146.995854
#
#        co_mixratio_error  planet_mass_real  temp_profile_real  \
# count         299.000000      2.990000e+02         299.000000
# mean           44.946664      2.672012e+27        1520.995921
# std           115.904347      7.460256e+26         312.953531
# min           -60.973078      1.518400e+27        1000.000000
# 25%           -33.741196      2.024533e+27        1222.222224
# 50%            -6.448407      2.783733e+27        1555.555582
# 75%            78.235741      3.289867e+27        1777.777791
# max           399.970290      3.796000e+27        2000.000000
#
#                ...            h2o_mixratio_real  co2_mixratio_real  \
# count          ...                   299.000000         299.000000
# mean           ...                   -10.035198         -10.753954
# std            ...                     5.359477           4.903923
# min            ...                   -18.420681         -18.420681
# 25%            ...                   -14.838882         -14.838882
# 50%            ...                    -9.466183         -11.257083
# 75%            ...                    -5.884384          -7.675284
# max            ...                    -2.302585          -2.302585
#
#        co_mixratio_real  planet_mass_inpainted  temp_profile_inpainted  \
# count        299.000000           2.990000e+02              299.000000
# mean         -10.472441           2.840518e+27             1539.090907
# std            5.344182           1.167563e+26               70.019800
# min          -18.420681           2.483743e+27             1390.344650
# 25%          -14.838882           2.759840e+27             1486.579120
# 50%          -11.257083           2.833612e+27             1524.859905
# 75%           -5.884384           2.920773e+27             1590.746462
# max           -2.302585           3.119902e+27             1738.314986
#
#        ch4_mixratio_inpainted  planet_radius_inpainted  \
# count              299.000000             2.990000e+02
# mean               -10.319700             8.350403e+07
# std                  4.499224             2.814984e+06
# min                -18.946603             7.636269e+07
# 25%                -14.047381             8.134933e+07
# 50%                -10.459735             8.332425e+07
# 75%                 -5.891893             8.564393e+07
# max                 -3.638888             9.060250e+07
#
#        h2o_mixratio_inpainted  co2_mixratio_inpainted  co_mixratio_inpainted
# count              299.000000              299.000000             299.000000
# mean               -10.037147              -10.754715              -9.981728
# std                  4.158729                4.208165               1.237916
# min                -18.670960              -18.252468             -12.090480
# 25%                -13.552876              -14.460260             -10.881487
# 50%                 -9.864541              -10.216314             -10.167876
# 75%                 -6.180877               -7.293353              -9.185581
# max                 -3.960854               -3.358731              -5.163591
#
# [8 rows x 22 columns]

# %%
params = ['planet_mass','temp_profile','ch4_mixratio','planet_radius','h2o_mixratio','co2_mixratio','co_mixratio']

plt.figure(figsize=((25,10)))
for i,param in enumerate(params):
    plt.subplot(3,3,i+1)
    plt.title(param+'_error')
    plt.hist(df[param+'_error'], bins=20)
    plt.grid()
    plt.tight_layout()

# %% [markdown]
# # Grab the $n$ sigma errors

# %%
Where the redline represents perfect predictions

# %%
plt.figure(figsize=((25,10)))

for i,param in enumerate(params):
    y_hat = df[param+'_real']
    y = df[param+'_inpainted']
    
    r2 = r2_score(y_hat, y)
    
    plt.subplot(3,3,i+1)
    plt.title(param +' \t $R^2$ = %.2f' % r2)
    plt.plot(y_hat, y, '.')
    plt.plot(plt.xlim(), plt.ylim(), ls="-", c='r')
    
    plt.xlabel(r"$\hat{y}$")
    plt.ylabel(r"$y$")
    plt.grid()
    plt.tight_layout()

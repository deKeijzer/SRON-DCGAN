# %%
import numpy as np
import seaborn as sns
import pandas as pd

import matplotlib.pyplot as plt

import keijzer_exogan as ke

from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm

# %matplotlib inline
# %config InlineBackend.print_figure_kwargs={'facecolor' : "w"} # Make sure the axis background of plots is white, this is usefull for the black theme in JupyterLab

# Initialize default seaborn layout
sns.set_palette(sns.hls_palette(8, l=.3, s=.8))
sns.set(style='ticks')

# %%
df = pd.read_csv('Validation error of 335 images')
df.head()
# Out:
#    Unnamed: 0  planet_mass_error  temp_profile_error  ch4_mixratio_error  \
# 0           0         -19.825910            7.601056          -23.327035
# 1           0           8.444330           52.418149          -20.373261
# 2           0          20.094964            4.949193           -5.939462
# 3           0          39.098941           52.090746          271.811461
# 4           0         -29.626787            3.963588           94.781028
#
#    planet_radius_error  h2o_mixratio_error  co2_mixratio_error  \
# 0           -25.513056          -17.000099          -23.035188
# 1            18.409403          121.449267          171.623337
# 2            27.882089           80.817885          173.601395
# 3             3.354786           87.288217            3.783009
# 4            -8.783983           -8.774212            7.203345
#
#    co_mixratio_error  planet_mass_real  temp_profile_real  \
# 0         -35.158888      3.036800e+27        1444.444448
# 1          38.007350      2.277600e+27        1000.000000
# 2         -22.714804      2.024533e+27        1444.444448
# 3          37.496642      2.024533e+27        1000.000000
# 4         226.855326      3.796000e+27        1555.555582
#
#            ...            h2o_mixratio_real  co2_mixratio_real  \
# 0          ...                   -13.047982         -11.257083
# 1          ...                    -5.884384          -2.302585
# 2          ...                    -7.675284          -2.302585
# 3          ...                    -5.884384         -16.629781
# 4          ...                   -13.047982          -5.884384
#
#    co_mixratio_real  planet_mass_inpainted  temp_profile_inpainted  \
# 0        -16.629781           2.434727e+27             1554.237485
# 1         -9.466183           2.469928e+27             1524.181485
# 2        -18.420681           2.431363e+27             1515.932798
# 3         -5.884384           2.816104e+27             1520.907462
# 4         -2.302585           2.671367e+27             1617.211401
#
#    ch4_mixratio_inpainted  planet_radius_inpainted  h2o_mixratio_inpainted  \
# 0              -14.123682             7.406161e+07              -10.829812
# 1              -14.667787             7.266350e+07              -13.030925
# 2              -15.642062             7.152292e+07              -13.878286
# 3               -8.561275             7.466491e+07              -11.020757
# 4               -7.973331             7.581548e+07              -11.903124
#
#    co2_mixratio_inpainted  co_mixratio_inpainted
# 0               -8.663992             -10.782935
# 1               -6.254358             -13.064029
# 2               -6.299905             -14.236459
# 3              -17.258887              -8.090830
# 4               -6.308256              -7.526122
#
# [5 rows x 22 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0  planet_mass_error  temp_profile_error  ch4_mixratio_error  \
# count       334.0         334.000000          334.000000          334.000000
# mean          0.0          11.142030            8.094022           35.132295
# std           0.0          34.766601           24.758985           77.896176
# min           0.0         -40.989064          -31.800377          -66.796646
# 25%           0.0         -17.257169          -12.322170          -13.087659
# 50%           0.0           3.982222            2.279034           11.107042
# 75%           0.0          34.780702           23.361537           47.171315
# max           0.0         104.645312           72.318172          329.989153
#
#        planet_radius_error  h2o_mixratio_error  co2_mixratio_error  \
# count           334.000000          334.000000          334.000000
# mean             -1.720420           41.156749           17.205550
# std              17.346371           95.746104           45.038885
# min             -33.695539          -58.982316          -45.186086
# 25%             -16.114672          -19.703925          -10.154375
# 50%              -5.972908            2.009980            2.730340
# 75%              10.413856           54.863468           26.003928
# max              42.173033          351.129907          205.855179
#
#        co_mixratio_error  planet_mass_real  temp_profile_real  \
# count         334.000000      3.340000e+02         334.000000
# mean           24.778312      2.629166e+27        1530.938132
# std           110.244123      7.284844e+26         317.765996
# min           -75.838117      1.518400e+27        1000.000000
# 25%           -43.190187      2.024533e+27        1333.333343
# 50%           -14.612131      2.530667e+27        1555.555582
# 75%            47.972126      3.289867e+27        1777.777791
# max           614.969213      3.796000e+27        2000.000000
#
#                ...            h2o_mixratio_real  co2_mixratio_real  \
# count          ...                   334.000000         334.000000
# mean           ...                   -10.490320         -10.490320
# std            ...                     5.239073           4.896990
# min            ...                   -18.420681         -18.420681
# 25%            ...                   -14.838882         -14.838882
# 50%            ...                   -11.257083         -11.257083
# 75%            ...                    -5.884384          -5.884384
# max            ...                    -2.302585          -2.302585
#
#        co_mixratio_real  planet_mass_inpainted  temp_profile_inpainted  \
# count        334.000000           3.340000e+02              334.000000
# mean         -10.286565           2.685749e+27             1580.311449
# std            4.941180           2.084058e+26               84.648571
# min          -18.420681           2.194390e+27             1330.521077
# 25%          -14.838882           2.539975e+27             1520.070210
# 50%           -9.466183           2.678367e+27             1583.553314
# 75%           -5.884384           2.842671e+27             1640.158683
# max           -2.302585           3.189901e+27             1787.092268
#
#        ch4_mixratio_inpainted  planet_radius_inpainted  \
# count              334.000000             3.340000e+02
# mean               -10.670892             7.602780e+07
# std                  3.460716             3.880520e+06
# min                -18.225705             6.746415e+07
# 25%                -13.567878             7.336576e+07
# 50%                -10.171027             7.568713e+07
# 75%                 -8.092189             7.863944e+07
# max                 -4.240292             8.761614e+07
#
#        h2o_mixratio_inpainted  co2_mixratio_inpainted  co_mixratio_inpainted
# count              334.000000              334.000000             334.000000
# mean               -10.692494              -10.846006              -8.910011
# std                  2.168622                4.153084               3.081990
# min                -15.398822              -18.231008             -16.462774
# 25%                -12.320329              -14.768644             -11.174050
# 50%                -10.765588              -10.548596              -8.479600
# 75%                 -9.070489               -6.893517              -6.469722
# max                 -5.454758               -4.249483              -3.685726
#
# [8 rows x 22 columns]

# %%
params = ['planet_mass','temp_profile','ch4_mixratio','planet_radius','h2o_mixratio','co2_mixratio','co_mixratio']

plt.figure(figsize=((25,10)))
for i,param in enumerate(params):
    plt.subplot(3,3,i+1)
    plt.title(param+'_error')
    plt.hist(df[param+'_error'], bins=20)
    plt.grid()
    plt.tight_layout()

# %% [markdown]
# # Grab the $n$ sigma errors

# %%
plt.figure(figsize=((25,10)))

for i,param in enumerate(params):
    plt.subplot(3,3,i+1)
    plt.title(param)
    plt.plot(df[param+'_real'], df[param+'_inpainted'], '.')
    plt.grid()
    plt.tight_layout()

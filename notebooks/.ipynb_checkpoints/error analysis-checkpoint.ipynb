# %%
import numpy as np
import seaborn as sns
import pandas as pd

import matplotlib.pyplot as plt

import keijzer_exogan as ke

from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm

from sklearn.metrics import r2_score

# %matplotlib inline
# %config InlineBackend.print_figure_kwargs={'facecolor' : "w"} # Make sure the axis background of plots is white, this is usefull for the black theme in JupyterLab

# Initialize default seaborn layout
sns.set_palette(sns.hls_palette(8, l=.3, s=.8))
sns.set(style='ticks')

# %%
df = pd.read_csv('Validation error of 307 images')
df.head()
# Out:
#    Unnamed: 0  planet_mass_error  temp_profile_error  ch4_mixratio_error  \
# 0           0          11.323945            4.450263           -1.930887
# 1           0          -4.089127            0.371148            9.804664
# 2           0           7.411985           -9.188712           10.641960
# 3           0         -32.538530          -16.225140           -2.476159
# 4           0           1.397450          -10.014875            8.422790
#
#    planet_radius_error  h2o_mixratio_error  co2_mixratio_error  \
# 0            -0.833780           -3.976743           -0.557513
# 1            -2.292246           -4.120937           -0.041595
# 2             1.940056           -5.321642            0.131374
# 3             8.774233           -2.817324           -2.669855
# 4            -2.739201           -0.054266            8.768016
#
#    co_mixratio_error  planet_mass_real  temp_profile_real  \
# 0          41.694440      3.542933e+27        1111.111112
# 1          39.581499      2.024533e+27        1888.888896
# 2          10.433179      3.036800e+27        1222.222224
# 3         -17.840282      2.277600e+27        1666.666687
# 4         -50.734508      2.783733e+27        1111.111112
#
#            ...            h2o_mixratio_real  co2_mixratio_real  \
# 0          ...                    -7.675284         -14.838882
# 1          ...                    -5.884384         -18.420681
# 2          ...                    -7.675284         -18.420681
# 3          ...                    -9.466183         -14.838882
# 4          ...                    -9.466183          -2.302585
#
#    co_mixratio_real  planet_mass_inpainted  temp_profile_inpainted  \
# 0        -13.047982           3.944133e+27             1160.558477
# 1        -13.047982           1.941748e+27             1895.899475
# 2        -13.047982           3.261887e+27             1109.915741
# 3         -5.884384           1.536502e+27             1396.247685
# 4        -11.257083           2.822635e+27              999.834721
#
#    ch4_mixratio_inpainted  planet_radius_inpainted  h2o_mixratio_inpainted  \
# 0              -12.796040             9.320777e+07               -7.370058
# 1              -14.327293             6.527254e+07               -5.641892
# 2              -18.399516             8.472892e+07               -7.266833
# 3              -10.978339             7.266537e+07               -9.199490
# 4               -4.438270             7.555111e+07               -9.461046
#
#    co2_mixratio_inpainted  co_mixratio_inpainted
# 0              -14.756153             -18.488265
# 1              -18.413019             -18.212569
# 2              -18.444881             -14.409301
# 3              -14.442705              -4.834593
# 4               -2.504476              -5.545857
#
# [5 rows x 22 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0  planet_mass_error  temp_profile_error  ch4_mixratio_error  \
# count       306.0         306.000000          306.000000          306.000000
# mean          0.0          12.222667            3.348489           -3.929956
# std           0.0          35.637290           30.477279           27.808247
# min           0.0         -57.166515          -49.816738         -107.030404
# 25%           0.0         -11.940479          -17.690655          -10.307011
# 50%           0.0           5.758398           -0.429355           -2.370827
# 75%           0.0          27.718217           17.154161            2.650969
# max           0.0         148.770189          114.862227          182.732612
#
#        planet_radius_error  h2o_mixratio_error  co2_mixratio_error  \
# count           306.000000          306.000000          306.000000
# mean             -0.644430            1.536363            8.172877
# std               3.523735           27.745270           41.129312
# min             -20.345925          -90.261954          -53.620740
# 25%              -2.057472           -6.269801           -4.202761
# 50%              -0.329723           -0.219462           -0.545321
# 75%               1.219556            6.514745            5.042270
# max               8.774233          212.124273          327.468818
#
#        co_mixratio_error  planet_mass_real  temp_profile_real  \
# count         306.000000      3.060000e+02         306.000000
# mean            9.756738      2.664643e+27        1521.423392
# std            75.874868      7.172803e+26         328.817265
# min          -103.220329      1.518400e+27        1000.000000
# 25%           -28.180449      2.024533e+27        1222.222224
# 50%            -5.269767      2.783733e+27        1555.555582
# 75%            22.837983      3.289867e+27        1777.777791
# max           522.078851      3.796000e+27        2000.000000
#
#                ...            h2o_mixratio_real  co2_mixratio_real  \
# count          ...                   306.000000         306.000000
# mean           ...                   -10.859105         -10.098265
# std            ...                     5.225742           5.129260
# min            ...                   -18.420681         -18.420681
# 25%            ...                   -14.838882         -14.838882
# 50%            ...                   -11.257083          -9.466183
# 75%            ...                    -5.884384          -5.884384
# max            ...                    -2.302585          -2.302585
#
#        co_mixratio_real  planet_mass_inpainted  temp_profile_inpainted  \
# count        306.000000           3.060000e+02              306.000000
# mean         -10.209465           2.877220e+27             1528.926636
# std            5.032407           8.423777e+26              409.233354
# min          -18.420681           1.494892e+27              992.178495
# 25%          -14.838882           2.097258e+27             1128.024742
# 50%           -9.466183           2.944216e+27             1526.735127
# 75%           -5.884384           3.553184e+27             1907.897443
# max           -2.302585           4.846616e+27             2693.265319
#
#        ch4_mixratio_inpainted  planet_radius_inpainted  \
# count              306.000000             3.060000e+02
# mean                -9.702601             8.045309e+07
# std                  5.019622             1.645277e+07
# min                -18.469462             5.558956e+07
# 25%                -13.872359             6.725578e+07
# 50%                 -9.635535             7.969098e+07
# 75%                 -5.511648             9.581958e+07
# max                  0.161881             1.068732e+08
#
#        h2o_mixratio_inpainted  co2_mixratio_inpainted  co_mixratio_inpainted
# count              306.000000              306.000000             306.000000
# mean               -10.746971              -10.229692              -9.884121
# std                  5.313264                4.748045               5.414417
# min                -18.515332              -18.462402             -18.568422
# 25%                -15.459415              -14.539249             -14.581805
# 50%                -11.439665               -9.908866              -9.249983
# 75%                 -6.020792               -6.121532              -4.899353
# max                 -1.533857               -1.714056               0.420188
#
# [8 rows x 22 columns]

# %%
params = ['planet_mass','temp_profile','ch4_mixratio','planet_radius','h2o_mixratio','co2_mixratio','co_mixratio']

plt.figure(figsize=((25,10)))
for i,param in enumerate(params):
    plt.subplot(3,3,i+1)
    plt.title(param+'_error')
    plt.hist(df[param+'_error'], bins=20)
    plt.grid()
    plt.tight_layout()

# %% [markdown]
# # Grab the $n$ sigma errors

# %% [raw]
# Where the redline represents perfect predictions

# %%
plt.figure(figsize=((25,10)))

for i,param in enumerate(params):
    y_hat = df[param+'_real']
    y = df[param+'_inpainted']
    
    r2 = r2_score(y_hat, y)
    
    plt.subplot(3,3,i+1)

    plt.title(param +' \t $R^2$ = %.2f' % r2)
    plt.plot(y_hat, y, '.')
    #plt.ylim(plt.xlim()) # set y axis range the same as x axis range
    plt.plot(plt.xlim(), plt.ylim(), ls="-", c='r')
    
    plt.xlabel(r"$\hat{y}$")
    plt.ylabel(r"$y$")
    plt.grid()
    plt.tight_layout()
